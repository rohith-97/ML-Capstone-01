# %%
import warnings
warnings.filterwarnings('ignore')


import numpy as np 
import pandas as pd 


import matplotlib.pyplot as plt
import seaborn as sns


from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.pipeline import Pipeline


pd.options.display.float_format = "{:.2f}".format

# %%
df = pd.read_csv("diabetes_prediction_dataset.csv")

# %%
df.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history   bmi  \
# 0  Female 80.00             0              1           never 25.19
# 1  Female 54.00             0              0         No Info 27.32
# 2    Male 28.00             0              0           never 27.32
# 3  Female 36.00             0              0         current 23.45
# 4    Male 76.00             1              1         current 20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0         6.60                  140         0
# 1         6.60                   80         0
# 2         5.70                  158         0
# 3         5.00                  155         0
# 4         4.80                  155         0

# %%
duplicate_rows_data = df[df.duplicated()]
print("number of duplicate rows: ", duplicate_rows_data.shape)
# Out:
# number of duplicate rows:  (3854, 9)

# %%
df = df.drop_duplicates()

# %%
for column in df.columns:
    num_distinct_values = len(df[column].unique())
    print(f"{column}: {num_distinct_values} distinct values")
# Out:
# gender: 3 distinct values
# age: 102 distinct values
# hypertension: 2 distinct values
# heart_disease: 2 distinct values
# smoking_history: 6 distinct values
# bmi: 4247 distinct values
# HbA1c_level: 18 distinct values
# blood_glucose_level: 18 distinct values
# diabetes: 2 distinct values

# %%
print(df.isnull().sum())
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
df = df[df['gender'] != 'Other']

# %%
df.describe().style.format("{:.2f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_0f595">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0f595_level0_col0" class="col_heading level0 col0" >age</th>
#       <th id="T_0f595_level0_col1" class="col_heading level0 col1" >hypertension</th>
#       <th id="T_0f595_level0_col2" class="col_heading level0 col2" >heart_disease</th>
#       <th id="T_0f595_level0_col3" class="col_heading level0 col3" >bmi</th>
#       <th id="T_0f595_level0_col4" class="col_heading level0 col4" >HbA1c_level</th>
#       <th id="T_0f595_level0_col5" class="col_heading level0 col5" >blood_glucose_level</th>
#       <th id="T_0f595_level0_col6" class="col_heading level0 col6" >diabetes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0f595_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_0f595_row0_col0" class="data row0 col0" >96128.00</td>
#       <td id="T_0f595_row0_col1" class="data row0 col1" >96128.00</td>
#       <td id="T_0f595_row0_col2" class="data row0 col2" >96128.00</td>
#       <td id="T_0f595_row0_col3" class="data row0 col3" >96128.00</td>
#       <td id="T_0f595_row0_col4" class="data row0 col4" >96128.00</td>
#       <td id="T_0f595_row0_col5" class="data row0 col5" >96128.00</td>
#       <td id="T_0f595_row0_col6" class="data row0 col6" >96128.00</td>
#     </tr>
#     <tr>
#       <th id="T_0f595_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_0f595_row1_col0" class="data row1 col0" >41.80</td>
#       <td id="T_0f595_row1_col1" class="data row1 col1" >0.08</td>
#       <td id="T_0f595_row1_col2" class="data row1 col2" >0.04</td>
#       <td id="T_0f595_row1_col3" class="data row1 col3" >27.32</td>
#       <td id="T_0f595_row1_col4" class="data row1 col4" >5.53</td>
#       <td id="T_0f595_row1_col5" class="data row1 col5" >138.22</td>
#       <td id="T_0f595_row1_col6" class="data row1 col6" >0.09</td>
#     </tr>
#     <tr>
#       <th id="T_0f595_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_0f595_row2_col0" class="data row2 col0" >22.46</td>
#       <td id="T_0f595_row2_col1" class="data row2 col1" >0.27</td>
#       <td id="T_0f595_row2_col2" class="data row2 col2" >0.20</td>
#       <td id="T_0f595_row2_col3" class="data row2 col3" >6.77</td>
#       <td id="T_0f595_row2_col4" class="data row2 col4" >1.07</td>
#       <td id="T_0f595_row2_col5" class="data row2 col5" >40.91</td>
#       <td id="T_0f595_row2_col6" class="data row2 col6" >0.28</td>
#     </tr>
#     <tr>
#       <th id="T_0f595_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_0f595_row3_col0" class="data row3 col0" >0.08</td>
#       <td id="T_0f595_row3_col1" class="data row3 col1" >0.00</td>
#       <td id="T_0f595_row3_col2" class="data row3 col2" >0.00</td>
#       <td id="T_0f595_row3_col3" class="data row3 col3" >10.01</td>
#       <td id="T_0f595_row3_col4" class="data row3 col4" >3.50</td>
#       <td id="T_0f595_row3_col5" class="data row3 col5" >80.00</td>
#       <td id="T_0f595_row3_col6" class="data row3 col6" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_0f595_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_0f595_row4_col0" class="data row4 col0" >24.00</td>
#       <td id="T_0f595_row4_col1" class="data row4 col1" >0.00</td>
#       <td id="T_0f595_row4_col2" class="data row4 col2" >0.00</td>
#       <td id="T_0f595_row4_col3" class="data row4 col3" >23.40</td>
#       <td id="T_0f595_row4_col4" class="data row4 col4" >4.80</td>
#       <td id="T_0f595_row4_col5" class="data row4 col5" >100.00</td>
#       <td id="T_0f595_row4_col6" class="data row4 col6" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_0f595_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_0f595_row5_col0" class="data row5 col0" >43.00</td>
#       <td id="T_0f595_row5_col1" class="data row5 col1" >0.00</td>
#       <td id="T_0f595_row5_col2" class="data row5 col2" >0.00</td>
#       <td id="T_0f595_row5_col3" class="data row5 col3" >27.32</td>
#       <td id="T_0f595_row5_col4" class="data row5 col4" >5.80</td>
#       <td id="T_0f595_row5_col5" class="data row5 col5" >140.00</td>
#       <td id="T_0f595_row5_col6" class="data row5 col6" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_0f595_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_0f595_row6_col0" class="data row6 col0" >59.00</td>
#       <td id="T_0f595_row6_col1" class="data row6 col1" >0.00</td>
#       <td id="T_0f595_row6_col2" class="data row6 col2" >0.00</td>
#       <td id="T_0f595_row6_col3" class="data row6 col3" >29.86</td>
#       <td id="T_0f595_row6_col4" class="data row6 col4" >6.20</td>
#       <td id="T_0f595_row6_col5" class="data row6 col5" >159.00</td>
#       <td id="T_0f595_row6_col6" class="data row6 col6" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_0f595_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_0f595_row7_col0" class="data row7 col0" >80.00</td>
#       <td id="T_0f595_row7_col1" class="data row7 col1" >1.00</td>
#       <td id="T_0f595_row7_col2" class="data row7 col2" >1.00</td>
#       <td id="T_0f595_row7_col3" class="data row7 col3" >95.69</td>
#       <td id="T_0f595_row7_col4" class="data row7 col4" >9.00</td>
#       <td id="T_0f595_row7_col5" class="data row7 col5" >300.00</td>
#       <td id="T_0f595_row7_col6" class="data row7 col6" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.hist(df['age'], bins=30, edgecolor='black')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
sns.countplot(x='gender', data=df)
plt.title('Gender Distribution')
plt.show()

# %%
sns.distplot(df['bmi'], bins=30)
plt.title('BMI Distribution')
plt.show()

# %%
for col in ['hypertension', 'heart_disease', 'diabetes']:
    sns.countplot(x=col, data=df)
    plt.title(f'{col} Distribution')
    plt.show()

# %%
sns.countplot(x='smoking_history', data=df)
plt.title('Smoking History Distribution')
plt.show()

# %%
sns.boxplot(x='diabetes', y='bmi', data=df)
plt.title('BMI vs Diabetes')
plt.show()

# %%
sns.boxplot(x='diabetes', y='age', data=df)
plt.title('Age vs Diabetes')
plt.show()

# %%
sns.countplot(x='gender', hue='diabetes', data=df)
plt.title('Gender vs Diabetes')
plt.show()

# %%
sns.boxplot(x='diabetes', y='HbA1c_level', data=df)
plt.title('HbA1c level vs Diabetes')
plt.show()

# %%
sns.boxplot(x='diabetes', y='blood_glucose_level', data=df)
plt.title('Blood Glucose Level vs Diabetes')
plt.show()

# %%
sns.scatterplot(x='age', y='bmi', hue='diabetes', data=df)
plt.title('Age vs BMI')
plt.show()

# %%
sns.violinplot(x='diabetes', y='bmi', hue='gender', split=True, data=df)
plt.title('BMI vs Diabetes split by Gender')
plt.show()

# %%
sns.boxplot(x='diabetes', y='bmi', hue='gender', data=df)
plt.title('BMI Distribution by Diabetes Status and Gender')
plt.show()

# %%
sns.boxplot(x='diabetes', y='age', hue='gender', data=df)
plt.title('Age Distribution by Diabetes Status and Gender')
plt.show()
